# %%
from datetime import datetime
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup
import re

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""
    
# source: https://stackoverflow.com/questions/3368969/find-string-between-two-substrings

# %%
states = {
    'AK': 'ALASKA',
    'AL': 'ALABAMA',
    'AR': 'ARKANSAS',
    'AZ': 'ARIZONA',
    'CA': 'CALIFORNIA',
    'CO': 'COLORADO',
    'CT': 'CONNECTICUT',
    'DC': 'DISTRICT OF COLUMBIA',
    'DE': 'DELAWARE',
    'FL': 'FLORIDA',
    'GA': 'GEORGIA',
    'HI': 'HAWAII',
    'IA': 'IOWA',
    'ID': 'IDAHO',
    'IL': 'ILLINOIS',
    'IN': 'INDIANA',
    'KS': 'KANSAS',
    'KY': 'KENTUCKY',
    'LA': 'LOUISIANA',
    'MA': 'MASSACHUSETTS',
    'MD': 'MARYLAND',
    'ME': 'MAINE',
    'MI': 'MICHIGAN',
    'MN': 'MINNESOTA',
    'MO': 'MISSOURI',
    'MS': 'MISSISSIPPI',
    'MT': 'MONTANA',
    'NC': 'NORTH CAROLINA',
    'ND': 'NORTH DAKOTA',
    'NE': 'NEBRASKA',
    'NH': 'NEW HAMPSHIRE',
    'NJ': 'NEW JERSEY',
    'NM': 'NEW MEXICO',
    'NV': 'NEVADA',
    'NY': 'NEW YORK',
    'OH': 'OHIO',
    'OK': 'OKLAHOMA',
    'OR': 'OREGON',
    'PA': 'PENNSYLVANIA',
    'RI': 'RHODE ISLAND',
    'SC': 'SOUTH CAROLINA',
    'SD': 'SOUTH DAKOTA',
    'TN': 'TENNESSEE',
    'TX': 'TEXAS',
    'UT': 'UTAH',
    'VA': 'VIRGINIA',
    'VT': 'VERMONT',
    'WA': 'WASHINGTON',
    'WI': 'WISCONSIN',
    'WV': 'WEST VIRGINIA',
    'WY': 'WYOMING'
}

# thanks to https://gist.github.com/JeffPaine/3083347

# %%
filename = "../big-ufo-data/nuforcData_2022_demo.csv"

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("program start at", current_time)
# Out:
# program start at 10:44:55

# %%
allUrl = "http://www.nuforc.org/webreports/ndxloc.html"
allPage = urllib.request.urlopen(allUrl)
allSoup = BeautifulSoup(allPage, 'html.parser')

table = allSoup.find("table")

stateLinks = []
for link in table.find_all("a"):
#     if link.get_text() in states.values():
#         stateLinks.append(link['href'])
    if link.get_text() == "MICHIGAN":
        stateLinks.append(link['href'])
        break

reportLinks = []
for state in stateLinks:
    stateUrl = 'http://www.nuforc.org/webreports/' + state
    statePage = urllib.request.urlopen(stateUrl)
    stateSoup = BeautifulSoup(statePage, 'html.parser')
    stateTable = stateSoup.find("tbody")
    for x in stateTable.find_all("tr"):
        link = x.find("a")['href']
        reportLinks.append('http://www.nuforc.org/webreports/' + link)

# %%
len(reportLinks)
# Out:
# 3415

# %%
rows = []

now = datetime.now()
loop_start = now
current_time = now.strftime("%H:%M:%S")
print("going into loop at ", current_time)

counter = 0

for link in reportLinks[:500]:
    reportPage = urllib.request.urlopen(link)
    reportSoup = BeautifulSoup(reportPage, 'html.parser')
    report = reportSoup.find("tbody").find_all("td")
    text = list(report[0].stripped_strings)
    textString = " ".join(text)
    occured = ""
    reported = ""
    posted = ""
    town = ""
    state = ""
    shape = ""
    duration = ""
    characteristics = ""
    
    for line in text:
        if "Occurred" in line:
            occurred = find_between(line, ":", "(").strip()
        if "Reported" in line:
            reported_date = find_between(line, ": ", " ").strip()
            if "AM" in line:
                reported_time = line.split("AM")[1].strip()
            if "PM" in line:
                reported_time = line.split("PM")[1].strip()
            reported = reported_date + " " + reported_time
        if "Posted" in line:
            posted = line.split(":")[1].strip()
        if "Location" in line:
            location = line.split(":")[1].strip()
            local = location.split(", ")
            town = local[0].strip()
            if len(local) > 1:
                state = local[1].strip()
        if "Shape" in line:
            shape = line.split(":")[1].strip()
        if "Duration" in line:
            duration = line.split(":")[1].strip()
        if "Characteristic" in line:
            characteristics = line.split(":")[1].strip()
      
    summary = report[1].get_text().strip()
    
    img_urls = []
    img_links = reportSoup.find_all("img", {"class": "ufopic"})
    for i in img_links: 
        img_urls.append(i["src"])
    
    reportRow = [link, occurred, reported, posted, town, state, "USA", shape, 
                 duration, characteristics, summary, img_urls]
    rows.append(reportRow)
    
    if counter % 50 == 0:
        now = datetime.now()
        current_time = now.strftime("%H:%M:%S")
        print("counter at ", counter, " at ", current_time)
    counter+= 1
# Out:
# going into loop at  10:47:42
# counter at  0  at  10:47:42
# counter at  10  at  10:47:43
# counter at  20  at  10:47:44
# counter at  30  at  10:47:44
# counter at  40  at  10:47:45
# counter at  50  at  10:47:45
# counter at  60  at  10:47:46
# counter at  70  at  10:47:47
# counter at  80  at  10:47:48
# counter at  90  at  10:47:48
# counter at  100  at  10:47:49
# counter at  110  at  10:47:49
# counter at  120  at  10:47:50
# counter at  130  at  10:47:51
# counter at  140  at  10:47:51
# counter at  150  at  10:47:52
# counter at  160  at  10:47:52
# counter at  170  at  10:47:53
# counter at  180  at  10:47:54
# counter at  190  at  10:47:54
# counter at  200  at  10:47:55
# counter at  210  at  10:47:55
# counter at  220  at  10:47:56
# counter at  230  at  10:47:57
# counter at  240  at  10:47:57
# counter at  250  at  10:47:58
# counter at  260  at  10:47:58
# counter at  270  at  10:47:59
# counter at  280  at  10:48:00
# counter at  290  at  10:48:00
# counter at  300  at  10:48:01
# counter at  310  at  10:48:01
# counter at  320  at  10:48:02
# counter at  330  at  10:48:02
# counter at  340  at  10:48:03
# counter at  350  at  10:48:04
# counter at  360  at  10:48:04
# counter at  370  at  10:48:05
# counter at  380  at  10:48:06
# counter at  390  at  10:48:06
# counter at  400  at  10:48:07
# counter at  410  at  10:48:08
# counter at  420  at  10:48:08
# counter at  430  at  10:48:09
# counter at  440  at  10:48:10
# counter at  450  at  10:48:10
# counter at  460  at  10:48:11
# counter at  470  at  10:48:11
# counter at  480  at  10:48:12
# counter at  490  at  10:48:12

# %%
now = datetime.now()
loop_end = now
current_time = now.strftime("%H:%M:%S")
print("loop done at", current_time)
# Out:
# loop done at 10:48:13

# %%
df = pd.DataFrame(rows, 
             columns=["Link", "Occurred", "Reported", "Posted", "City", "State", 
                      "Country", "Shape", "Duration", "Characteristics", "Summary", "Images"])

# %%
df.to_csv(filename)

# %%
df.head(10)
# Out:
#                                                 Link         Occurred  \
# 0  http://www.nuforc.org/webreports/reports/167/S...   5/8/2022 15:30
# 1  http://www.nuforc.org/webreports/reports/167/S...   5/8/2022 04:30
# 2  http://www.nuforc.org/webreports/reports/167/S...   5/6/2022 22:30
# 3  http://www.nuforc.org/webreports/reports/167/S...   5/4/2022 17:30
# 4  http://www.nuforc.org/webreports/reports/167/S...  4/28/2022 21:12
# 5  http://www.nuforc.org/webreports/reports/167/S...  4/22/2022 05:35
# 6  http://www.nuforc.org/webreports/reports/167/S...  4/21/2022 21:50
# 7  http://www.nuforc.org/webreports/reports/167/S...  4/21/2022 21:50
# 8  http://www.nuforc.org/webreports/reports/167/S...  4/21/2022 21:49
# 9  http://www.nuforc.org/webreports/reports/167/S...   4/6/2022 20:46
#
#           Reported     Posted         City State Country      Shape  \
# 0   5/8/2022 01:02  5/31/2022     Bessemer    MI     USA  Rectangle
# 1   5/8/2022 02:36  5/31/2022       Monroe    MI     USA      Light
# 2   5/7/2022 21:03  5/31/2022    Fife Lake    MI     USA     Circle
# 3   5/5/2022 15:07  5/31/2022    Roseville    MI     USA       Cone
# 4  4/28/2022 19:24  5/31/2022      Holland    MI     USA      Other
# 5  4/22/2022 10:31  4/22/2022  Howard City    MI     USA      Cross
# 6  4/22/2022 06:01  4/22/2022    Flat Rock    MI     USA      Cigar
# 7  4/21/2022 19:54  4/22/2022     Muskegon    MI     USA  Formation
# 8  4/21/2022 23:36  4/22/2022    Riverview    MI     USA       Star
# 9   4/6/2022 19:12  4/22/2022       Macomb    MI     USA       Oval
#
#                    Duration  \
# 0               5-7 seconds
# 1  Approximately 6 seconds.
# 2               2-3 minutes
# 3                    3-5min
# 4                       N/a
# 5                 5 minutes
# 6               3-5 minutes
# 7                  2-3 mins
# 8                 3 minutes
# 9                     3 min
#
#                                      Characteristics  \
# 0
# 1                    There were lights on the object
# 2
# 3
# 4  There was an aura or haze around the object, T...
# 5  There were lights on the object, The object ch...
# 6  There were lights on the object, The object le...
# 7  There were lights on the object, There were ai...
# 8  There were lights on the object, There was an ...
# 9
#
#                                              Summary  \
# 0  Bright shiny reflective rectangle coming from ...
# 1  Very fast moving light, high up\n\nThe time is...
# 2  small white dots similar to lights seen by air...
# 3  Ship seen hovering above highway\n\nI heard th...
# 4  I had video going in the background and have b...
# 5  It was Shaped like a capitalized letter "T"\n\...
# 6  Saw an amber string of lights fly west to east...
# 7  Long, tight row of lights flew from over the l...
# 8  Connected lights in the sky.\n\nI went to take...
# 9  The the green object appeared on phone photos\...
#
#                                               Images
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [https://nuforc.org/wp-content/uploads/wpforms...
# 5  [https://nuforc.org/wp-content/uploads/wpforms...
# 6  [https://nuforc.org/wp-content/uploads/wpforms...
# 7  [https://nuforc.org/wp-content/uploads/wpforms...
# 8                                                 []
# 9  [https://nuforc.org/wp-content/uploads/wpforms...
